# %% [markdown]
# <a href="https://colab.research.google.com/github/sv-zeynalova/sql_hometask/blob/main/Homework_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sqlite3
conn_sqlite = sqlite3.connect('Task1_7.db')  
c = conn_sqlite.cursor()

# %%
import psycopg2
import pandas as pd
#Библиотека ждя визуализации
from IPython.display import HTML
import plotly.express as px
import plotly.graph_objects as go

#!введите свои реквизиты!
DB_HOST = '52.157.159.24'
DB_USER = 'student8'
DB_USER_PASSWORD = 'student8_password'
DB_NAME = 'sql_ex_for_student8'

conn = psycopg2.connect(host=DB_HOST, user=DB_USER, password=DB_USER_PASSWORD, dbname=DB_NAME)
conn_psql = psycopg2.connect(host=DB_HOST, user=DB_USER, password=DB_USER_PASSWORD, dbname=DB_NAME)
# Out:
# /usr/local/lib/python3.7/dist-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %%
df = pd.read_sql('select * from table1', conn_psql)

df.to_sql(name='table1', con=conn_sqlite)

# %%
pd.read_sql('select * from table1', conn_sqlite)
# Out:
#      index   r1   r2   r3
# 0        0  408  790  303
# 1        1  980  907  815
# 2        2  395  910  946
# 3        3  897  347  242
# 4        4  441  569  850
# ..     ...  ...  ...  ...
# 995    995  515  958  953
# 996    996  187  561  597
# 997    997  180  285  333
# 998    998  144  266  821
# 999    999  753  348  312
#
# [1000 rows x 4 columns]

# %%
fig = go.Figure(data=[go.Histogram(x=df['r1']),
                      go.Histogram(x=df['r2']),
                      go.Histogram(x=df['r3'])
                      ])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f1f8dae5-65a8-4208-880a-ee6a25726ea1" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f1f8dae5-65a8-4208-880a-ee6a25726ea1")) {
#                     Plotly.newPlot(
#                         'f1f8dae5-65a8-4208-880a-ee6a25726ea1',
# ...

# %%
# Гистограмма показывает частоту попадания в определенный интервал данных в разбивке по колонкам r1, r2, r3
